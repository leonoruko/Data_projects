# %%
authorization='Bearer authorizationkey'


import requests
import pandas as pd
import json

headers = {
    "accept": "application/json",
    "Authorization": authorization
}
url="https://api.themoviedb.org//3/movie/now_playing"
response=requests.get(url,headers=headers)
if response.status_code==200:
    data=response.json()
    df=pd.DataFrame(data['results'])
    columns=['id']+[col for col in df.columns if col !='id']
    df=df[columns]
    df.to_csv('movies.csv')
    print(df)
else:
    print(f'Error: {response.status_code}')
# Out:
#          id  adult                     backdrop_path                genre_ids  \
# 0    365177  False  /mKOBdgaEFguADkJhfFslY7TYxIh.jpg    [28, 878, 35, 12, 53]
# 1    917496  False  /18wozP6NjPSNBSgCga5bN7yUSzl.jpg             [35, 14, 27]
# 2    646097  False  /tbgIhYwQ5IAgNaFU1SBBxxNXCmm.jpg             [80, 28, 53]
# 3    519182  False  /lgkPzcOSnTvjeMnuFzozRO5HHw1.jpg      [16, 10751, 35, 28]
# 4    970347  False  /tCQfubckzzcuCbsGugkpLhfjS5z.jpg             [28, 53, 80]
# 5    923667  False  /9juRmk8QjcsUcbrevVu5t8VZy5G.jpg         [28, 12, 80, 53]
# 6      4011  False  /yRKyJJYIzfeiVDHBe4LXguPQCvD.jpg                 [14, 35]
# 7    718821  False  /7aPrv2HFssWcOtpig5G3HEVk3uS.jpg             [28, 12, 53]
# 8      5492  False  /bxwKC4qAbceMgHU1xCCTBK1eYdn.jpg             [28, 53, 80]
# 9   1079091  False  /9BQqngPfwpeAfK7c2H3cwIFWIVR.jpg              [10749, 18]
# 10   704239  False  /4ft6TR9wA6bra0RLL6G7JFDQ5t1.jpg                 [28, 35]
# ...

# %%
df
# Out:
#          id  adult                     backdrop_path                genre_ids  \
# 0    365177  False  /mKOBdgaEFguADkJhfFslY7TYxIh.jpg    [28, 878, 35, 12, 53]
# 1    917496  False  /18wozP6NjPSNBSgCga5bN7yUSzl.jpg             [35, 14, 27]
# 2    646097  False  /tbgIhYwQ5IAgNaFU1SBBxxNXCmm.jpg             [80, 28, 53]
# 3    519182  False  /lgkPzcOSnTvjeMnuFzozRO5HHw1.jpg      [16, 10751, 35, 28]
# 4    970347  False  /tCQfubckzzcuCbsGugkpLhfjS5z.jpg             [28, 53, 80]
# 5    923667  False  /9juRmk8QjcsUcbrevVu5t8VZy5G.jpg         [28, 12, 80, 53]
# 6      4011  False  /yRKyJJYIzfeiVDHBe4LXguPQCvD.jpg                 [14, 35]
# 7    718821  False  /7aPrv2HFssWcOtpig5G3HEVk3uS.jpg             [28, 12, 53]
# 8      5492  False  /bxwKC4qAbceMgHU1xCCTBK1eYdn.jpg             [28, 53, 80]
# 9   1079091  False  /9BQqngPfwpeAfK7c2H3cwIFWIVR.jpg              [10749, 18]
# 10   704239  False  /4ft6TR9wA6bra0RLL6G7JFDQ5t1.jpg                 [28, 35]
# ...

# %%
df.dtypes
# Out:
# id                     int64
# adult                   bool
# backdrop_path         object
# genre_ids             object
# original_language     object
# original_title        object
# overview              object
# popularity           float64
# poster_path           object
# release_date          object
# title                 object
# video                   bool
# vote_average         float64
# vote_count             int64
# dtype: object

# %%
import ast
# oonverting the object columns to appropriate datatypes
df['genre_ids'] = df['genre_ids'].replace('\[|\]','',regex=True)
df['release_date']=pd.to_datetime(df['release_date'],format="%Y-%m-%d")

# other conversion are already correct
print(df.dtypes)
# Out:
# id                            int64
# adult                          bool
# backdrop_path                object
# genre_ids                    object
# original_language            object
# original_title               object
# overview                     object
# popularity                  float64
# poster_path                  object
# release_date         datetime64[ns]
# title                        object
# video                          bool
# vote_average                float64
# vote_count                    int64
# dtype: object
# <>:3: SyntaxWarning: invalid escape sequence '\['
# <>:3: SyntaxWarning: invalid escape sequence '\['
# C:\Users\User\AppData\Local\Temp\ipykernel_9524\1660531055.py:3: SyntaxWarning: invalid escape sequence '\['
#   df['genre_ids'] = df['genre_ids'].replace('\[|\]','',regex=True)

# %%
df
# Out:
#          id  adult                     backdrop_path                genre_ids  \
# 0    365177  False  /mKOBdgaEFguADkJhfFslY7TYxIh.jpg    [28, 878, 35, 12, 53]
# 1    917496  False  /18wozP6NjPSNBSgCga5bN7yUSzl.jpg             [35, 14, 27]
# 2    646097  False  /tbgIhYwQ5IAgNaFU1SBBxxNXCmm.jpg             [80, 28, 53]
# 3    519182  False  /lgkPzcOSnTvjeMnuFzozRO5HHw1.jpg      [16, 10751, 35, 28]
# 4    970347  False  /tCQfubckzzcuCbsGugkpLhfjS5z.jpg             [28, 53, 80]
# 5    923667  False  /9juRmk8QjcsUcbrevVu5t8VZy5G.jpg         [28, 12, 80, 53]
# 6      4011  False  /yRKyJJYIzfeiVDHBe4LXguPQCvD.jpg                 [14, 35]
# 7    718821  False  /7aPrv2HFssWcOtpig5G3HEVk3uS.jpg             [28, 12, 53]
# 8      5492  False  /bxwKC4qAbceMgHU1xCCTBK1eYdn.jpg             [28, 53, 80]
# 9   1079091  False  /9BQqngPfwpeAfK7c2H3cwIFWIVR.jpg              [10749, 18]
# 10   704239  False  /4ft6TR9wA6bra0RLL6G7JFDQ5t1.jpg                 [28, 35]
# ...

# %%
# !pip install sqlalchemy
import psycopg2
from sqlalchemy import create_engine

engine=create_engine('postgresql://postgres:root@localhost:5432/etl_pipeline')

# using the dataframe to create the pipeline
df.to_sql('movies',engine,if_exists='replace',index=False)
# Out:
# 20

# %%
# The encoding is the reason the \copy to the database was not working so we change that to windows-1252 instead of utf-8
with open('movies.csv','r',encoding='utf-8') as infile ,open('movies_win1252.csv','w',encoding='windows-1252',errors='replace') as outfile:
    outfile.write(infile.read())

# %%
# !pip install sqlalchemy
import psycopg2
from sqlalchemy import create_engine

engine=create_engine('postgresql+psycopg2://postgres:root@localhost:5432/etl_pipeline')
new_df=pd.read_csv('movies_win1252.csv',encoding='windows-1252')
# using the dataframe to create the pipeline
new_df.to_sql('movies',engine,if_exists='replace',index=False)
# Out:
# 20
